# %%
import cv2
import time
import numpy as np
import os

MODE = "COCO"

protoFile = "pose/coco/pose_deploy_linevec.prototxt"
weightsFile = "pose/coco/pose_iter_440000.caffemodel"
nPoints = 18
POSE_PAIRS = [ [1,0],[1,2],[1,5],[2,3],[3,4],[5,6],[6,7],[1,8],[8,9],[9,10],[1,11],[11,12],[12,13],[0,14],[0,15],[14,16],[15,17]]

directory = 'augImg/AugTree'
startTime = time.time()

image_num = 0
for filename in os.scandir(directory):
    if (filename.path.endswith(".jpg") or filename.path.endswith(".png")) and filename.is_file():
        print('Dtecting Kps on image: ' + str(image_num))
        frame = cv2.imread(filename.path)
        frameCopy = np.copy(frame)
        frameWidth = frame.shape[1]
        frameHeight = frame.shape[0]
        threshold = 0.1
#         threshold = 0.5 #moet getest worden

        net = cv2.dnn.readNetFromCaffe(protoFile, weightsFile)

        t = time.time()
        # input image dimensions for the network
        inWidth = 640
        inHeight = 480
        inpBlob = cv2.dnn.blobFromImage(frame, 1.0 / 255, (inWidth, inHeight),
                                  (0, 0, 0), swapRB=False, crop=False)

        net.setInput(inpBlob)

        output = net.forward()
        print("time taken by network : {:.3f}".format(time.time() - t))

        H = output.shape[2]
        W = output.shape[3]

        # Empty list to store the detected keypoints
        points = []

        for i in range(nPoints):
            # confidence map of corresponding body's part.
            probMap = output[0, i, :, :]

            # Find global maxima of the probMap.
            minVal, prob, minLoc, point = cv2.minMaxLoc(probMap)

            # Scale the point to fit on the original image
            x = (frameWidth * point[0]) / W
            y = (frameHeight * point[1]) / H

            if prob > threshold : 
                cv2.circle(frameCopy, (int(x), int(y)), 8, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
                cv2.putText(frameCopy, "{}".format(i), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, lineType=cv2.LINE_AA)

                # Add the point to the list if the probability is greater than the threshold
                points.append((int(x), int(y)))
            else :
                points.append(None)

        # Draw Skeleton
        for pair in POSE_PAIRS:
            partA = pair[0]
            partB = pair[1]

            if points[partA] and points[partB]:
                cv2.line(frame, points[partA], points[partB], (0, 255, 255), 2)
                cv2.circle(frame, points[partA], 8, (0, 0, 255), thickness=-1, lineType=cv2.FILLED)

        cv2.imwrite("augImg/TreeCheck/" + os.path.basename(filename.path),frame)
        image_num +=1
print("Total time taken : {:.3f}".format(time.time() - startTime))

print("Done with Exporting")
# Out:
# Dtecting Kps on image: 0
# time taken by network : 4.680
# Dtecting Kps on image: 1
# time taken by network : 4.925
# Dtecting Kps on image: 2
# time taken by network : 4.952
# Dtecting Kps on image: 3
# time taken by network : 5.287
# Dtecting Kps on image: 4
# time taken by network : 4.892
# Dtecting Kps on image: 5
# time taken by network : 5.169
# Dtecting Kps on image: 6
# time taken by network : 4.656
# Dtecting Kps on image: 7
# time taken by network : 4.623
# Dtecting Kps on image: 8
# time taken by network : 4.609
# Dtecting Kps on image: 9
# time taken by network : 4.585
# Dtecting Kps on image: 10
# time taken by network : 4.669
# Dtecting Kps on image: 11
# time taken by network : 4.655
# Dtecting Kps on image: 12
# time taken by network : 4.821
# Dtecting Kps on image: 13
# time taken by network : 4.545
# Dtecting Kps on image: 14
# time taken by network : 4.537
# Dtecting Kps on image: 15
# time taken by network : 4.503
# Dtecting Kps on image: 16
# time taken by network : 4.562
# Dtecting Kps on image: 17
# time taken by network : 4.683
# Dtecting Kps on image: 18
# time taken by network : 4.612
# Dtecting Kps on image: 19
# time taken by network : 4.606
# Dtecting Kps on image: 20
# time taken by network : 4.692
# Dtecting Kps on image: 21
# time taken by network : 4.654
# Dtecting Kps on image: 22
# time taken by network : 4.595
# Dtecting Kps on image: 23
# time taken by network : 4.607
# Dtecting Kps on image: 24
# time taken by network : 4.589
# Dtecting Kps on image: 25
# time taken by network : 4.653
# Dtecting Kps on image: 26
# time taken by network : 4.601
# Dtecting Kps on image: 27
# time taken by network : 4.605
# Dtecting Kps on image: 28
# time taken by network : 4.572
# Dtecting Kps on image: 29
# time taken by network : 4.593
# Dtecting Kps on image: 30
# time taken by network : 4.616
# Dtecting Kps on image: 31
# time taken by network : 4.643
# Dtecting Kps on image: 32
# time taken by network : 4.621
# Dtecting Kps on image: 33
# time taken by network : 4.553
# Dtecting Kps on image: 34
# time taken by network : 4.633
# Dtecting Kps on image: 35
# time taken by network : 4.560
# Dtecting Kps on image: 36
# time taken by network : 4.597
# Dtecting Kps on image: 37
# time taken by network : 4.553
# Dtecting Kps on image: 38
# time taken by network : 4.762
# Dtecting Kps on image: 39
# time taken by network : 4.606
# Dtecting Kps on image: 40
# time taken by network : 4.635
# Dtecting Kps on image: 41
# time taken by network : 4.582
# Dtecting Kps on image: 42
# time taken by network : 4.695
# Dtecting Kps on image: 43
# time taken by network : 4.595
# Dtecting Kps on image: 44
# time taken by network : 4.603
# Dtecting Kps on image: 45
# time taken by network : 4.604
# Dtecting Kps on image: 46
# time taken by network : 4.748
# Dtecting Kps on image: 47
# time taken by network : 4.749
# Dtecting Kps on image: 48
# time taken by network : 4.761
# Dtecting Kps on image: 49
# time taken by network : 4.748
# Dtecting Kps on image: 50
# time taken by network : 4.624
# Dtecting Kps on image: 51
# time taken by network : 4.568
# Dtecting Kps on image: 52
# time taken by network : 4.607
# Dtecting Kps on image: 53
# time taken by network : 4.585
# Dtecting Kps on image: 54
# time taken by network : 4.543
# Dtecting Kps on image: 55
# time taken by network : 4.664
# Dtecting Kps on image: 56
# time taken by network : 4.750
# Dtecting Kps on image: 57
# time taken by network : 4.695
# Dtecting Kps on image: 58
# time taken by network : 4.719
# Dtecting Kps on image: 59
# time taken by network : 4.641
# Dtecting Kps on image: 60
# time taken by network : 4.732
# Dtecting Kps on image: 61
# time taken by network : 4.795
# Dtecting Kps on image: 62
# time taken by network : 4.785
# Dtecting Kps on image: 63
# time taken by network : 4.676
# Dtecting Kps on image: 64
# time taken by network : 4.711
# Dtecting Kps on image: 65
# time taken by network : 4.624
# Dtecting Kps on image: 66
# time taken by network : 4.512
# Dtecting Kps on image: 67
# time taken by network : 4.600
# Dtecting Kps on image: 68
# time taken by network : 4.428
# Dtecting Kps on image: 69
# time taken by network : 4.693
# Dtecting Kps on image: 70
# time taken by network : 4.644
# Dtecting Kps on image: 71
# time taken by network : 4.641
# Dtecting Kps on image: 72
# time taken by network : 4.585
# Dtecting Kps on image: 73
# time taken by network : 4.676
# Dtecting Kps on image: 74
# time taken by network : 4.541
# Dtecting Kps on image: 75
# time taken by network : 4.617
# Dtecting Kps on image: 76
# time taken by network : 4.700
# Dtecting Kps on image: 77
# time taken by network : 4.681
# Dtecting Kps on image: 78
# time taken by network : 4.629
# Dtecting Kps on image: 79
# time taken by network : 4.677
# Dtecting Kps on image: 80
# time taken by network : 4.566
# Dtecting Kps on image: 81
# time taken by network : 4.560
# Dtecting Kps on image: 82
# time taken by network : 4.459
# Dtecting Kps on image: 83
# time taken by network : 4.506
# Dtecting Kps on image: 84
# time taken by network : 4.625
# Dtecting Kps on image: 85
# time taken by network : 4.554
# Dtecting Kps on image: 86
# time taken by network : 4.529
# Dtecting Kps on image: 87
# time taken by network : 4.534
# Dtecting Kps on image: 88
# time taken by network : 4.566
# Dtecting Kps on image: 89
# time taken by network : 4.518
# Dtecting Kps on image: 90
# time taken by network : 4.596
# Dtecting Kps on image: 91
# time taken by network : 4.593
# Dtecting Kps on image: 92
# time taken by network : 4.504
# Dtecting Kps on image: 93
# time taken by network : 4.517
# Dtecting Kps on image: 94
# time taken by network : 4.472
# Dtecting Kps on image: 95
# time taken by network : 4.542
# Dtecting Kps on image: 96
# time taken by network : 4.631
# Dtecting Kps on image: 97
# time taken by network : 4.521
# Dtecting Kps on image: 98
# time taken by network : 4.516
# Dtecting Kps on image: 99
# time taken by network : 4.615
# Dtecting Kps on image: 100
# time taken by network : 4.492
# Dtecting Kps on image: 101
# time taken by network : 4.571
# Dtecting Kps on image: 102
# time taken by network : 4.491
# Dtecting Kps on image: 103
# time taken by network : 4.520
# Dtecting Kps on image: 104
# time taken by network : 4.484
# Dtecting Kps on image: 105
# time taken by network : 4.543
# Dtecting Kps on image: 106
# time taken by network : 4.630
# Dtecting Kps on image: 107
# time taken by network : 4.589
# Dtecting Kps on image: 108
# time taken by network : 4.543
# Dtecting Kps on image: 109
# time taken by network : 4.599
# Dtecting Kps on image: 110
# time taken by network : 4.469
# Dtecting Kps on image: 111
# time taken by network : 4.542
# Dtecting Kps on image: 112
# time taken by network : 4.606
# Dtecting Kps on image: 113
# time taken by network : 4.520
# Dtecting Kps on image: 114
# time taken by network : 4.520
# Dtecting Kps on image: 115
# time taken by network : 4.566
# Dtecting Kps on image: 116
# time taken by network : 4.527
# Dtecting Kps on image: 117
# time taken by network : 4.473
# Dtecting Kps on image: 118
# time taken by network : 4.535
# Dtecting Kps on image: 119
# time taken by network : 4.412
# Dtecting Kps on image: 120
# time taken by network : 4.480
# Dtecting Kps on image: 121
# time taken by network : 4.569
# Dtecting Kps on image: 122
# time taken by network : 4.448
# Dtecting Kps on image: 123
# time taken by network : 4.442
# Dtecting Kps on image: 124
# time taken by network : 4.426
# Dtecting Kps on image: 125
# time taken by network : 4.472
# Dtecting Kps on image: 126
# time taken by network : 4.545
# Dtecting Kps on image: 127
# time taken by network : 4.482
# Dtecting Kps on image: 128
# time taken by network : 4.464
# Dtecting Kps on image: 129
# time taken by network : 4.496
# Dtecting Kps on image: 130
# time taken by network : 4.476
# Dtecting Kps on image: 131
# time taken by network : 4.401
# Dtecting Kps on image: 132
# time taken by network : 4.566
# Dtecting Kps on image: 133
# time taken by network : 4.503
# Dtecting Kps on image: 134
# time taken by network : 4.535
# Dtecting Kps on image: 135
# time taken by network : 4.534
# Dtecting Kps on image: 136
# time taken by network : 4.514
# Dtecting Kps on image: 137
# time taken by network : 4.516
# Dtecting Kps on image: 138
# time taken by network : 4.515
# Dtecting Kps on image: 139
# time taken by network : 4.491
# Dtecting Kps on image: 140
# time taken by network : 4.459
# Dtecting Kps on image: 141
# time taken by network : 4.539
# Dtecting Kps on image: 142
# time taken by network : 4.536
# Dtecting Kps on image: 143
# time taken by network : 4.467
# Dtecting Kps on image: 144
# time taken by network : 4.604
# Dtecting Kps on image: 145
# time taken by network : 4.511
# Dtecting Kps on image: 146
# time taken by network : 4.528
# Dtecting Kps on image: 147
# time taken by network : 4.548
# Dtecting Kps on image: 148
# time taken by network : 4.605
# Dtecting Kps on image: 149
# time taken by network : 4.504
# Dtecting Kps on image: 150
# time taken by network : 4.508
# Dtecting Kps on image: 151
# time taken by network : 4.613
# Dtecting Kps on image: 152
# time taken by network : 4.683
# Dtecting Kps on image: 153
# time taken by network : 4.510
# Dtecting Kps on image: 154
# time taken by network : 4.486
# Dtecting Kps on image: 155
# time taken by network : 4.579
# Dtecting Kps on image: 156
# time taken by network : 4.557
# Dtecting Kps on image: 157
# time taken by network : 4.492
# Dtecting Kps on image: 158
# time taken by network : 4.461
# Dtecting Kps on image: 159
# time taken by network : 4.569
# Dtecting Kps on image: 160
# time taken by network : 4.690
# Dtecting Kps on image: 161
# time taken by network : 4.602
# Dtecting Kps on image: 162
# time taken by network : 4.587
# Dtecting Kps on image: 163
# time taken by network : 4.624
# Dtecting Kps on image: 164
# time taken by network : 4.561
# Dtecting Kps on image: 165
# time taken by network : 4.575
# Dtecting Kps on image: 166
# time taken by network : 4.725
# Dtecting Kps on image: 167
# time taken by network : 4.669
# Dtecting Kps on image: 168
# time taken by network : 4.746
# Dtecting Kps on image: 169
# time taken by network : 4.698
# Dtecting Kps on image: 170
# time taken by network : 4.630
# Dtecting Kps on image: 171
# time taken by network : 4.621
# Dtecting Kps on image: 172
# time taken by network : 4.661
# Dtecting Kps on image: 173
# time taken by network : 4.571
# Dtecting Kps on image: 174
# time taken by network : 4.622
# Dtecting Kps on image: 175
# time taken by network : 4.637
# Dtecting Kps on image: 176
# time taken by network : 4.569
# Dtecting Kps on image: 177
# time taken by network : 4.684
# Dtecting Kps on image: 178
# time taken by network : 4.516
# Dtecting Kps on image: 179
# time taken by network : 4.794
# Dtecting Kps on image: 180
# time taken by network : 4.613
# Dtecting Kps on image: 181
# time taken by network : 4.735
# Dtecting Kps on image: 182
# time taken by network : 4.558
# Dtecting Kps on image: 183
# time taken by network : 4.610
# Dtecting Kps on image: 184
# time taken by network : 4.469
# Dtecting Kps on image: 185
# time taken by network : 4.691
# Dtecting Kps on image: 186
# time taken by network : 4.657
# Dtecting Kps on image: 187
# time taken by network : 4.606
# Dtecting Kps on image: 188
# time taken by network : 4.695
# Dtecting Kps on image: 189
# time taken by network : 4.545
# Dtecting Kps on image: 190
# time taken by network : 4.585
# Dtecting Kps on image: 191
# time taken by network : 4.720
# Dtecting Kps on image: 192
# time taken by network : 4.601
# Dtecting Kps on image: 193
# time taken by network : 4.594
# Dtecting Kps on image: 194
# time taken by network : 4.771
# Dtecting Kps on image: 195
# time taken by network : 4.659
# Dtecting Kps on image: 196
# time taken by network : 4.546
# Dtecting Kps on image: 197
# time taken by network : 4.616
# Dtecting Kps on image: 198
# time taken by network : 4.733
# Dtecting Kps on image: 199
# time taken by network : 4.564
# Dtecting Kps on image: 200
# time taken by network : 4.618
# Dtecting Kps on image: 201
# time taken by network : 4.750
# Dtecting Kps on image: 202
# time taken by network : 4.667
# Dtecting Kps on image: 203
# time taken by network : 4.605
# Dtecting Kps on image: 204
# time taken by network : 4.608
# Dtecting Kps on image: 205
# time taken by network : 4.556
# Dtecting Kps on image: 206
# time taken by network : 4.587
# Dtecting Kps on image: 207
# time taken by network : 4.556
# Dtecting Kps on image: 208
# time taken by network : 4.645
# Dtecting Kps on image: 209
# time taken by network : 4.600
# Dtecting Kps on image: 210
# time taken by network : 4.665
# Dtecting Kps on image: 211
# time taken by network : 4.634
# Dtecting Kps on image: 212
# time taken by network : 4.536
# Dtecting Kps on image: 213
# time taken by network : 4.690
# Dtecting Kps on image: 214
# time taken by network : 4.568
# Dtecting Kps on image: 215
# time taken by network : 4.737
# Dtecting Kps on image: 216
# time taken by network : 4.848
# Dtecting Kps on image: 217
# time taken by network : 4.726
# Dtecting Kps on image: 218
# time taken by network : 4.707
# Dtecting Kps on image: 219
# time taken by network : 4.625
# Dtecting Kps on image: 220
# time taken by network : 4.792
# Dtecting Kps on image: 221
# time taken by network : 4.614
# Dtecting Kps on image: 222
# time taken by network : 4.564
# Dtecting Kps on image: 223
# time taken by network : 4.577
# Dtecting Kps on image: 224
# time taken by network : 4.483
# Dtecting Kps on image: 225
# time taken by network : 4.480
# Dtecting Kps on image: 226
# time taken by network : 4.631
# Dtecting Kps on image: 227
# time taken by network : 4.567
# Dtecting Kps on image: 228
# time taken by network : 4.556
# Dtecting Kps on image: 229
# time taken by network : 4.677
# Dtecting Kps on image: 230
# time taken by network : 4.516
# Dtecting Kps on image: 231
# time taken by network : 4.741
# Dtecting Kps on image: 232
# time taken by network : 4.671
# Dtecting Kps on image: 233
# time taken by network : 4.649
# Dtecting Kps on image: 234
# time taken by network : 4.528
# Dtecting Kps on image: 235
# time taken by network : 4.752
# Dtecting Kps on image: 236
# time taken by network : 4.622
# Dtecting Kps on image: 237
# time taken by network : 4.491
# Dtecting Kps on image: 238
# time taken by network : 4.609
# Dtecting Kps on image: 239
# time taken by network : 4.595
# Dtecting Kps on image: 240
# time taken by network : 4.611
# Dtecting Kps on image: 241
# time taken by network : 4.655
# Dtecting Kps on image: 242
# time taken by network : 4.571
# Dtecting Kps on image: 243
# time taken by network : 4.640
# Dtecting Kps on image: 244
# time taken by network : 4.653
# Dtecting Kps on image: 245
# time taken by network : 4.610
# Dtecting Kps on image: 246
# time taken by network : 4.602
# Dtecting Kps on image: 247
# time taken by network : 4.513
# Dtecting Kps on image: 248
# time taken by network : 4.546
# Dtecting Kps on image: 249
# time taken by network : 4.611
# Dtecting Kps on image: 250
# time taken by network : 4.504
# Dtecting Kps on image: 251
# time taken by network : 4.816
# Dtecting Kps on image: 252
# time taken by network : 4.628
# Dtecting Kps on image: 253
# time taken by network : 4.798
# Dtecting Kps on image: 254
# time taken by network : 4.622
# Dtecting Kps on image: 255
# time taken by network : 4.528
# Dtecting Kps on image: 256
# time taken by network : 4.665
# Dtecting Kps on image: 257
# time taken by network : 4.666
# Dtecting Kps on image: 258
# time taken by network : 4.551
# Dtecting Kps on image: 259
# time taken by network : 4.626
# Dtecting Kps on image: 260
# time taken by network : 4.737
# Dtecting Kps on image: 261
# time taken by network : 4.577
# Dtecting Kps on image: 262
# time taken by network : 4.603
# Dtecting Kps on image: 263
# time taken by network : 4.701
# Dtecting Kps on image: 264
# time taken by network : 4.631
# Dtecting Kps on image: 265
# time taken by network : 4.780
# Dtecting Kps on image: 266
# time taken by network : 4.616
# Dtecting Kps on image: 267
# time taken by network : 4.660
# Dtecting Kps on image: 268
# time taken by network : 4.515
# Dtecting Kps on image: 269
# time taken by network : 4.537
# Dtecting Kps on image: 270
# time taken by network : 4.606
# Dtecting Kps on image: 271
# time taken by network : 4.660
# Dtecting Kps on image: 272
# time taken by network : 4.675
# Dtecting Kps on image: 273
# time taken by network : 4.620
# Dtecting Kps on image: 274
# time taken by network : 4.799
# Dtecting Kps on image: 275
# time taken by network : 4.579
# Dtecting Kps on image: 276
# time taken by network : 4.650
# Dtecting Kps on image: 277
# time taken by network : 4.678
# Dtecting Kps on image: 278
# time taken by network : 4.576
# Dtecting Kps on image: 279
# time taken by network : 4.594
# Dtecting Kps on image: 280
# time taken by network : 4.641
# Dtecting Kps on image: 281
# time taken by network : 4.548
# Dtecting Kps on image: 282
# time taken by network : 4.652
# Dtecting Kps on image: 283
# time taken by network : 4.566
# Dtecting Kps on image: 284
# time taken by network : 4.636
# Dtecting Kps on image: 285
# time taken by network : 4.600
# Dtecting Kps on image: 286
# time taken by network : 4.697
# Dtecting Kps on image: 287
# time taken by network : 4.515
# Dtecting Kps on image: 288
# time taken by network : 4.563
# Dtecting Kps on image: 289
# time taken by network : 4.598
# Dtecting Kps on image: 290
# time taken by network : 4.644
# Dtecting Kps on image: 291
# time taken by network : 4.599
# Dtecting Kps on image: 292
# time taken by network : 4.668
# Dtecting Kps on image: 293
# time taken by network : 4.517
# Dtecting Kps on image: 294
# time taken by network : 4.604
# Dtecting Kps on image: 295
# time taken by network : 4.689
# Dtecting Kps on image: 296
# time taken by network : 4.634
# Dtecting Kps on image: 297
# time taken by network : 4.651
# Dtecting Kps on image: 298
# time taken by network : 4.663
# Dtecting Kps on image: 299
# time taken by network : 4.628
# Dtecting Kps on image: 300
# time taken by network : 4.714
# Dtecting Kps on image: 301
# time taken by network : 4.652
# Dtecting Kps on image: 302
# time taken by network : 4.630
# Dtecting Kps on image: 303
# time taken by network : 4.584
# Dtecting Kps on image: 304
# time taken by network : 4.620
# Dtecting Kps on image: 305
# time taken by network : 4.610
# Dtecting Kps on image: 306
# time taken by network : 4.536
# Dtecting Kps on image: 307
# time taken by network : 4.492
# Dtecting Kps on image: 308
# time taken by network : 4.491
# Dtecting Kps on image: 309
# time taken by network : 4.556
# Dtecting Kps on image: 310
# time taken by network : 4.492
# Dtecting Kps on image: 311
# time taken by network : 4.465
# Dtecting Kps on image: 312
# time taken by network : 4.524
# Dtecting Kps on image: 313
# time taken by network : 4.505
# Dtecting Kps on image: 314
# time taken by network : 4.552
# Dtecting Kps on image: 315
# time taken by network : 4.482
# Dtecting Kps on image: 316
# time taken by network : 4.477
# Dtecting Kps on image: 317
# time taken by network : 4.574
# Dtecting Kps on image: 318
# time taken by network : 4.455
# Dtecting Kps on image: 319
# time taken by network : 4.521
# Dtecting Kps on image: 320
# time taken by network : 4.533
# Dtecting Kps on image: 321
# time taken by network : 4.663
# Dtecting Kps on image: 322
# time taken by network : 4.538
# Dtecting Kps on image: 323
# time taken by network : 4.536
# Dtecting Kps on image: 324
# time taken by network : 4.599
# Dtecting Kps on image: 325
# time taken by network : 4.528
# Dtecting Kps on image: 326
# time taken by network : 4.593
# Dtecting Kps on image: 327
# time taken by network : 4.532
# Dtecting Kps on image: 328
# time taken by network : 4.617
# Dtecting Kps on image: 329
# time taken by network : 4.638
# Dtecting Kps on image: 330
# time taken by network : 4.695
# Dtecting Kps on image: 331
# time taken by network : 4.594
# Dtecting Kps on image: 332
# time taken by network : 4.542
# Dtecting Kps on image: 333
# time taken by network : 4.584
# Dtecting Kps on image: 334
# time taken by network : 4.562
# Dtecting Kps on image: 335
# time taken by network : 4.470
# Dtecting Kps on image: 336
# time taken by network : 4.559
# Dtecting Kps on image: 337
# time taken by network : 4.478
# Dtecting Kps on image: 338
# time taken by network : 4.517
# Dtecting Kps on image: 339
# time taken by network : 4.685
# Dtecting Kps on image: 340
# time taken by network : 4.503
# Dtecting Kps on image: 341
# time taken by network : 4.612
# Dtecting Kps on image: 342
# time taken by network : 4.552
# Dtecting Kps on image: 343
# time taken by network : 4.508
# Dtecting Kps on image: 344
# time taken by network : 4.604
# Dtecting Kps on image: 345
# time taken by network : 4.625
# Dtecting Kps on image: 346
# time taken by network : 4.606
# Dtecting Kps on image: 347
# time taken by network : 4.745
# Dtecting Kps on image: 348
# time taken by network : 4.744
# Dtecting Kps on image: 349
# time taken by network : 4.624
# Dtecting Kps on image: 350
# time taken by network : 4.655
# Dtecting Kps on image: 351
# time taken by network : 4.591
# Dtecting Kps on image: 352
# time taken by network : 4.612
# Dtecting Kps on image: 353
# time taken by network : 4.600
# Dtecting Kps on image: 354
# time taken by network : 4.612
# Dtecting Kps on image: 355
# time taken by network : 4.632
# Dtecting Kps on image: 356
# time taken by network : 4.737
# Dtecting Kps on image: 357
# time taken by network : 4.643
# Dtecting Kps on image: 358
# time taken by network : 4.700
# Dtecting Kps on image: 359
# time taken by network : 4.604
# Dtecting Kps on image: 360
# time taken by network : 4.668
# Dtecting Kps on image: 361
# time taken by network : 4.603
# Dtecting Kps on image: 362
# time taken by network : 4.602
# Dtecting Kps on image: 363
# time taken by network : 4.560
# Dtecting Kps on image: 364
# time taken by network : 4.567
# Dtecting Kps on image: 365
# time taken by network : 4.571
# Dtecting Kps on image: 366
# time taken by network : 4.712
# Dtecting Kps on image: 367
# time taken by network : 4.697
# Dtecting Kps on image: 368
# time taken by network : 4.766
# Dtecting Kps on image: 369
# time taken by network : 4.731
# Dtecting Kps on image: 370
# time taken by network : 4.750
# Dtecting Kps on image: 371
# time taken by network : 4.752
# Dtecting Kps on image: 372
# time taken by network : 4.767
# Dtecting Kps on image: 373
# time taken by network : 4.589
# Dtecting Kps on image: 374
# time taken by network : 4.702
# Dtecting Kps on image: 375
# time taken by network : 4.746
# Dtecting Kps on image: 376
# time taken by network : 4.664
# Dtecting Kps on image: 377
# time taken by network : 4.592
# Dtecting Kps on image: 378
# time taken by network : 4.611
# Dtecting Kps on image: 379
# time taken by network : 4.590
# Dtecting Kps on image: 380
# time taken by network : 4.686
# Dtecting Kps on image: 381
# time taken by network : 4.688
# Dtecting Kps on image: 382
# time taken by network : 4.710
# Dtecting Kps on image: 383
# time taken by network : 4.667
# Dtecting Kps on image: 384
# time taken by network : 4.646
# Dtecting Kps on image: 385
# time taken by network : 4.546
# Dtecting Kps on image: 386
# time taken by network : 4.537
# Dtecting Kps on image: 387
# time taken by network : 4.595
# Dtecting Kps on image: 388
# time taken by network : 4.451
# Dtecting Kps on image: 389
# time taken by network : 4.547
# Dtecting Kps on image: 390
# time taken by network : 4.579
# Dtecting Kps on image: 391
# time taken by network : 4.509
# Dtecting Kps on image: 392
# time taken by network : 4.637
# Dtecting Kps on image: 393
# time taken by network : 4.556
# Dtecting Kps on image: 394
# time taken by network : 4.472
# Dtecting Kps on image: 395
# time taken by network : 4.490
# Dtecting Kps on image: 396
# time taken by network : 4.564
# Dtecting Kps on image: 397
# time taken by network : 4.498
# Dtecting Kps on image: 398
# time taken by network : 4.543
# Dtecting Kps on image: 399
# time taken by network : 4.499
# Dtecting Kps on image: 400
# time taken by network : 4.628
# Dtecting Kps on image: 401
# time taken by network : 4.584
# Dtecting Kps on image: 402
# time taken by network : 4.572
# Dtecting Kps on image: 403
# time taken by network : 4.577
# Dtecting Kps on image: 404
# time taken by network : 4.613
# Dtecting Kps on image: 405
# time taken by network : 4.600
# Dtecting Kps on image: 406
# time taken by network : 4.533
# Dtecting Kps on image: 407
# time taken by network : 4.489
# Dtecting Kps on image: 408
# time taken by network : 4.521
# Dtecting Kps on image: 409
# time taken by network : 4.627
# Dtecting Kps on image: 410
# time taken by network : 4.525
# Dtecting Kps on image: 411
# time taken by network : 4.581
# Dtecting Kps on image: 412
# time taken by network : 4.684
# Dtecting Kps on image: 413
# time taken by network : 4.713
# Dtecting Kps on image: 414
# time taken by network : 4.549
# Dtecting Kps on image: 415
# time taken by network : 4.801
# Dtecting Kps on image: 416
# time taken by network : 4.593
# Dtecting Kps on image: 417
# time taken by network : 4.648
# Dtecting Kps on image: 418
# time taken by network : 4.701
# Dtecting Kps on image: 419
# time taken by network : 4.528
# Dtecting Kps on image: 420
# time taken by network : 4.646
# Dtecting Kps on image: 421
# time taken by network : 4.806
# Dtecting Kps on image: 422
# time taken by network : 4.668
# Dtecting Kps on image: 423
# time taken by network : 4.645
# Dtecting Kps on image: 424
# time taken by network : 4.514
# Dtecting Kps on image: 425
# time taken by network : 4.513
# Dtecting Kps on image: 426
# time taken by network : 4.520
# Dtecting Kps on image: 427
# time taken by network : 4.673
# Dtecting Kps on image: 428
# time taken by network : 4.584
# Dtecting Kps on image: 429
# time taken by network : 4.552
# Dtecting Kps on image: 430
# time taken by network : 4.759
# Dtecting Kps on image: 431
# time taken by network : 4.722
# Dtecting Kps on image: 432
# time taken by network : 4.645
# Dtecting Kps on image: 433
# time taken by network : 4.586
# Dtecting Kps on image: 434
# time taken by network : 4.553
# Dtecting Kps on image: 435
# time taken by network : 4.561
# Dtecting Kps on image: 436
# time taken by network : 4.677
# Dtecting Kps on image: 437
# time taken by network : 4.598
# Dtecting Kps on image: 438
# time taken by network : 4.518
# Dtecting Kps on image: 439
# time taken by network : 4.552
# Dtecting Kps on image: 440
# time taken by network : 4.672
# Dtecting Kps on image: 441
# time taken by network : 4.739
# Dtecting Kps on image: 442
# time taken by network : 4.772
# Dtecting Kps on image: 443
# time taken by network : 4.785
# Dtecting Kps on image: 444
# time taken by network : 4.645
# Dtecting Kps on image: 445
# time taken by network : 4.787
# Dtecting Kps on image: 446
# time taken by network : 4.614
# Dtecting Kps on image: 447
# time taken by network : 4.650
# Dtecting Kps on image: 448
# time taken by network : 4.625
# Dtecting Kps on image: 449
# time taken by network : 4.757
# Dtecting Kps on image: 450
# time taken by network : 4.625
# Dtecting Kps on image: 451
# time taken by network : 4.635
# Dtecting Kps on image: 452
# time taken by network : 4.644
# Dtecting Kps on image: 453
# time taken by network : 4.699
# Dtecting Kps on image: 454
# time taken by network : 4.587
# Dtecting Kps on image: 455
# time taken by network : 4.615
# Dtecting Kps on image: 456
# time taken by network : 4.632
# Dtecting Kps on image: 457
# time taken by network : 4.674
# Dtecting Kps on image: 458
# time taken by network : 4.599
# Dtecting Kps on image: 459
# time taken by network : 4.758
# Dtecting Kps on image: 460
# time taken by network : 4.616
# Dtecting Kps on image: 461
# time taken by network : 4.513
# Dtecting Kps on image: 462
# time taken by network : 4.452
# Dtecting Kps on image: 463
# time taken by network : 4.643
# Dtecting Kps on image: 464
# time taken by network : 4.592
# Dtecting Kps on image: 465
# time taken by network : 4.628
# Dtecting Kps on image: 466
# time taken by network : 4.594
# Dtecting Kps on image: 467
# time taken by network : 4.657
# Dtecting Kps on image: 468
# time taken by network : 4.683
# Dtecting Kps on image: 469
# time taken by network : 4.669
# Dtecting Kps on image: 470
# time taken by network : 4.565
# Dtecting Kps on image: 471
# time taken by network : 4.666
# Dtecting Kps on image: 472
# time taken by network : 4.509
# Dtecting Kps on image: 473
# time taken by network : 4.563
# Dtecting Kps on image: 474
# time taken by network : 4.515
# Dtecting Kps on image: 475
# time taken by network : 4.550
# Dtecting Kps on image: 476
# time taken by network : 4.604
# Dtecting Kps on image: 477
# time taken by network : 4.484
# Dtecting Kps on image: 478
# time taken by network : 4.569
# Dtecting Kps on image: 479
# time taken by network : 4.511
# Dtecting Kps on image: 480
# time taken by network : 4.500
# Dtecting Kps on image: 481
# time taken by network : 4.610
# Dtecting Kps on image: 482
# time taken by network : 4.582
# Dtecting Kps on image: 483
# time taken by network : 4.511
# Dtecting Kps on image: 484
# time taken by network : 4.598
# Total time taken : 2462.525
# Done with Exporting
